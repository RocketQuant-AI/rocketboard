# %%
# %load_ext autoreload
# %autoreload 2

from simple_select_stock import get_recent_prices, price_change_filter, volume_change_filter
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(get_recent_prices(ticker='googl', days=10))
# Out:
#   ticker       date     open     high      low   close  adj_close    volume
# 0  GOOGL 2025-11-18  287.915  288.800  278.200  284.28     284.28  49158743
# 1  GOOGL 2025-11-17  285.775  293.950  283.570  285.02     285.02  52670192
# 2  GOOGL 2025-11-14  271.405  278.560  270.700  276.41     276.41  31647227
# 3  GOOGL 2025-11-13  282.340  282.840  277.240  278.57     278.57  29494040
# 4  GOOGL 2025-11-12  291.675  292.005  283.690  286.71     286.71  24829923
# 5  GOOGL 2025-11-11  287.745  291.915  287.320  291.31     291.31  19842136
# 6  GOOGL 2025-11-10  284.420  290.800  282.855  290.10     290.10  29557309
# 7  GOOGL 2025-11-07  283.205  283.780  275.190  278.83     278.83  34479588
# 8  GOOGL 2025-11-06  285.330  288.350  281.140  284.75     284.75  37173648
# 9  GOOGL 2025-11-05  278.870  286.415  277.340  284.31     284.31  30283252

# %%
print(get_recent_prices(ticker='nvda', days=10))
# Out:
#   ticker       date     open    high     low   close  adj_close     volume
# 0   NVDA 2025-11-18  183.375  184.80  179.65  181.36     181.36  213598877
# 1   NVDA 2025-11-17  185.965  189.00  184.32  186.60     186.60  173628858
# 2   NVDA 2025-11-14  182.860  191.01  180.58  190.17     190.17  186591856
# 3   NVDA 2025-11-13  191.050  191.44  183.85  186.86     186.86  207423074
# 4   NVDA 2025-11-12  195.720  195.89  191.13  193.80     193.80  154935263
# 5   NVDA 2025-11-11  195.155  195.42  191.30  193.16     193.16  176483327
# 6   NVDA 2025-11-10  195.110  199.94  193.79  199.05     199.05  198897134
# 7   NVDA 2025-11-07  184.900  188.32  178.91  188.15     188.15  264942255
# 8   NVDA 2025-11-06  196.420  197.62  186.38  188.08     188.08  223029778
# 9   NVDA 2025-11-05  198.770  202.92  194.65  195.21     195.21  166849081

# %%
print(get_recent_prices(ticker='meta', days=6))
# Out:
#   ticker       date     open    high      low   close  adj_close    volume
# 0   META 2025-11-17  609.035  611.69  595.400  602.01     602.01  16501331
# 1   META 2025-11-14  601.790  613.68  595.200  609.46     609.46  20724146
# 2   META 2025-11-13  613.070  617.65  603.000  609.89     609.89  20973845
# 3   META 2025-11-12  628.130  628.99  607.770  609.01     609.01  24493272
# 4   META 2025-11-11  628.000  629.56  619.390  627.08     627.08  13302187
# 5   META 2025-11-10  631.090  635.00  618.105  631.76     631.76  19245000

# %%
print(get_recent_prices(ticker='aapl', days=4))
# Out:
#   ticker       date     open     high     low   close  adj_close    volume
# 0   AAPL 2025-11-17  268.815  270.490  265.73  267.46     267.46  45018260
# 1   AAPL 2025-11-14  271.050  275.960  269.60  272.41     272.41  47431331
# 2   AAPL 2025-11-13  274.110  276.699  272.09  272.95     272.95  49602794
# 3   AAPL 2025-11-12  275.000  275.730  271.70  273.47     273.47  48397982

# %%
get_recent_prices(ticker='ibit', days=10, export_to_csv=True)
# Out:
# ✓ Results saved to: /Users/terry/code/RocketQuant-AI/outputs/get_recent_prices_days_10_ticker_ibit.csv
#   ticker       date    open    high      low   close  adj_close     volume
# 0   IBIT 2025-11-17  53.385  54.445  51.7000  52.100     52.100   92045921
# 1   IBIT 2025-11-14  54.090  55.285  53.3800  53.475     53.475   94217090
# 2   IBIT 2025-11-13  58.120  58.700  55.4800  55.590     55.590   78277765
# 3   IBIT 2025-11-12  59.470  59.560  57.1700  57.590     57.590   41656415
# 4   IBIT 2025-11-11  59.330  59.410  58.2500  58.350     58.350   33993831
# 5   IBIT 2025-11-10  60.299  60.360  59.4000  60.190     60.190   51036740
# 6   IBIT 2025-11-07  56.880  58.960  56.3900  58.880     58.880   64022332
# 7   IBIT 2025-11-06  58.400  58.410  56.9044  57.260     57.260   54876210
# 8   IBIT 2025-11-05  58.255  59.390  57.9600  58.920     58.920   50997589
# 9   IBIT 2025-11-04  58.880  59.490  56.4850  57.180     57.180  105318024

# %%
print(get_recent_prices(ticker='onds', days=5))
# Out:
#   ticker       date   open   high   low  close  adj_close     volume
# 0   ONDS 2025-11-18  6.155  7.920  6.15  7.840      7.840  179881981
# 1   ONDS 2025-11-17  7.510  7.515  5.98  6.255      6.255  154730862
# 2   ONDS 2025-11-14  6.165  7.860  6.10  7.180      7.180  184450259
# 3   ONDS 2025-11-13  6.320  7.340  6.31  6.560      6.560  220831446
# 4   ONDS 2025-11-12  5.985  6.165  5.48  5.510      5.510   78891632

# %%
print(price_change_filter("2025-11-17", "2025-11-18", 0.2, 0.3, export_to_csv=True))
# Out:
# Found 29 stocks with price change in range [20.0%, 30.0%]
# ✓ Results saved to: /Users/terry/code/RocketQuant-AI/outputs/price_change_filter_date_from_2025-11-17_date_to_2025-11-18_price_left_bound_0.2_price_right_bound_0.3.csv
#    ticker start_date  start_price   end_date  end_price  price_change  \
# 0   ORGNW 2025-11-17     0.014600 2025-11-18     0.0189      0.004300
# 1   VSEEW 2025-11-17     0.190000 2025-11-18     0.2450      0.055000
# 2    LOBO 2025-11-17     0.393750 2025-11-18     0.5031      0.109350
# 3   ICUCW 2025-11-17     0.018900 2025-11-18     0.0241      0.005200
# 4   CELUW 2025-11-17     0.022249 2025-11-18     0.0283      0.006051
# 5    NWTG 2025-11-17     0.904200 2025-11-18     1.1500      0.245800
# 6   HPAIW 2025-11-17     0.130000 2025-11-18     0.1650      0.035000
# 7   GDEVW 2025-11-17     0.022000 2025-11-18     0.0279      0.005900
# 8   RNWWW 2025-11-17     0.011300 2025-11-18     0.0143      0.003000
# ...

# %%
print(volume_change_filter("2025-11-17", "2025-11-18", "2025-11-10", "2025-11-14", 2, export_to_csv=True))
# Out:
# Found 177 stocks with volume ratio >= 5.00x
# Top performer: FERAR with 1952.10x volume increase
# ✓ Results saved to: /Users/terry/code/RocketQuant-AI/outputs/volume_change_filter_date_w_2025-11-14_date_x_2025-11-17_date_y_2025-11-18_date_z_2025-11-10_volume_ratio_5.csv
#     ticker  avg_volume_xy  avg_volume_zw  actual_ratio  days_xy  days_zw
# 0    FERAR        33966.5           17.4   1952.097701        2        5
# 1     AMIX    156263779.5       126958.0   1230.830507        2        5
# 2     LOBO     61871465.5        59077.8   1047.287907        2        5
# 3     GLMD     60506549.5        62704.4    964.949023        2        5
# 4    FVNNR         5618.5            8.0    702.312500        2        5
# ..     ...            ...            ...           ...      ...      ...
# 172   KPRX       144166.0        27489.2      5.244460        2        5
# 173   BRTX       179868.5        34314.6      5.241748        2        5
# ...
